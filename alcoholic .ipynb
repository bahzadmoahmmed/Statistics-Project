# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_csv('last.CSV')

# %%
# seed to generate same random forall students
np.random.seed(42)

# %%
mydata.head(5)
# Out:
#     Age  Gender Education Level Car Accidents Deaths by Alcohol  Unnamed: 5
# 0  25.0    Male     High School           Yes                No         NaN
# 1  42.0  Female      Bachelor's            No               Yes         NaN
# 2  35.0    Male        Master's           Yes               Yes         NaN
# 3  50.0    Male       Doctorate            No                No         NaN
# 4  28.0  Female     High School           Yes                No         NaN

# %%
# mydata.head()
# mydata.columns
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                507 non-null    float64
#  1   Gender             507 non-null    object
#  2   Education Level    507 non-null    object
#  3   Car Accidents      507 non-null    object
#  4   Deaths by Alcohol  507 non-null    object
#  5   Unnamed: 5         0 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 23.9+ KB

# %%
mydata.describe()
# Out:
#               Age  Unnamed: 5
# count  507.000000         0.0
# mean    35.889546         NaN
# std      8.305412         NaN
# min     22.000000         NaN
# 25%     28.000000         NaN
# 50%     36.000000         NaN
# 75%     43.000000         NaN
# max     50.000000         NaN

# %%
# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
mydata.hist(['Age'], figsize=(10,20))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Gender", y="Age", data=mydata)
# sns.boxplot(x="Gender", orient= "h", data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(mydata['Age'],mydata['Car Accidents'] )
# Out:
# Car Accidents  No  Yes
# Age
# 22.0            9    9
# 23.0            0   18
# 24.0            0    9
# 25.0            0   19
# 26.0            9   19
# 27.0           18    0
# 28.0            9   10
# 29.0           10    9
# 30.0            9    0
# 31.0            0   18
# 32.0            0   18
# 33.0            0   19
# 34.0            0    9
# 35.0            0   19
# 36.0            0   18
# 37.0            0   19
# 38.0            9   18
# 39.0            0   18
# 40.0           18    0
# 41.0           10    9
# 42.0           19    0
# 43.0            0    9
# 44.0            9    9
# 45.0           10    9
# 46.0            0   18
# 47.0            0   18
# 48.0            0   10
# 49.0            0   18
# 50.0           19    0

# %%
pd.crosstab(mydata['Age'],mydata['Car Accidents'] )
# Out:
# Car Accidents  No  Yes
# Age
# 22.0            9    9
# 23.0            0   18
# 24.0            0    9
# 25.0            0   19
# 26.0            9   19
# 27.0           18    0
# 28.0            9   10
# 29.0           10    9
# 30.0            9    0
# 31.0            0   18
# 32.0            0   18
# 33.0            0   19
# 34.0            0    9
# 35.0            0   19
# 36.0            0   18
# 37.0            0   19
# 38.0            9   18
# 39.0            0   18
# 40.0           18    0
# 41.0           10    9
# 42.0           19    0
# 43.0            0    9
# 44.0            9    9
# 45.0           10    9
# 46.0            0   18
# 47.0            0   18
# 48.0            0   10
# 49.0            0   18
# 50.0           19    0

# %%
sns.countplot(x="Education Level", hue="Gender", data=mydata)
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Education Level', 'Gender'],
                     columns=[ 'Deaths by Alcohol'], aggfunc=len)
# Out:
#                          Age       Car Accidents       Unnamed: 5
# Deaths by Alcohol         No   Yes            No   Yes         No   Yes
# Education Level Gender
# Bachelor's      Female  37.0  28.0          37.0  28.0       37.0  28.0
#                 Male     9.0  72.0           9.0  72.0        9.0  72.0
# Doctorate       Female   NaN  27.0           NaN  27.0        NaN  27.0
#                 Male    28.0  46.0          28.0  46.0       28.0  46.0
# High School     Female  46.0  18.0          46.0  18.0       46.0  18.0
#                 Male    44.0  37.0          44.0  37.0       44.0  37.0
# Master's        Female  31.0  47.0          31.0  47.0       31.0  47.0
#                 Male    18.0  19.0          18.0  19.0       18.0  19.0

# %%
pd.pivot_table(mydata,'Age', index=['Education Level', 'Gender'],
                     columns=[ 'Deaths by Alcohol'])
# Out:
# Deaths by Alcohol              No        Yes
# Education Level Gender
# Bachelor's      Female  37.270270  42.321429
#                 Male    24.000000  39.125000
# Doctorate       Female        NaN  36.333333
#                 Male    34.892857  34.565217
# High School     Female  33.869565  34.500000
#                 Male    36.454545  38.216216
# Master's        Female  32.838710  34.702128
#                 Male    22.500000  42.105263

# %%
pd.pivot_table(mydata,'Age', index=['Education Level', 'Gender'],
                     columns=[ 'Car Accidents'])
# Out:
# Car Accidents                  No        Yes
# Education Level Gender
# Bachelor's      Female  35.736842  44.666667
#                 Male          NaN  37.444444
# Doctorate       Female        NaN  36.333333
#                 Male    36.178571  33.782609
# High School     Female  35.000000  33.351351
#                 Male    38.263158  36.372093
# Master's        Female  42.000000  32.913043
#                 Male    36.000000  29.315789

# %%
sns.pairplot(mydata)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
mydata['Age'].std()
# Out:
# 8.305412135614501

# %%
mydata['Age'].mean()
# Out:
# 35.88954635108481

# %%
sns.distplot(mydata['Age'])
# Out:
# C:\Users\CS\AppData\Local\Temp\ipykernel_3376\4247246823.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mydata['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Education Level')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Deaths by Alcohol')
# Out:
# array([<Axes: title={'center': 'Female'}>,
#        <Axes: title={'center': 'Male'}>], dtype=object)

# %%
mydata.hist(by='Car Accidents',column = 'Deaths by Alcohol', figsize=(5,6))
# Out:
# array([<Axes: title={'center': 'No'}>, <Axes: title={'center': 'Yes'}>],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <p> <b>Alcoholic can be harmfull to your health.</b> </p>
#     <p><b><i> </i></b></p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <p><b>Excessive alcohol consumption can lead to addiction and liver damage.</b></p>
# </div>

# %%
x = st.skewnorm.rvs(1, size=1000)
# arg1 default is 1 (normal) above that generate right skweed
# and below it will generate left skweed
# the amount of skeeness depend on the number ratio to size

# %%
# Print the first few values to check
x[3:10]
# Out:
# array([ 0.61949136, -0.328147  , -0.11267635,  1.74966929,  0.99179259,
#        -0.41017732,  0.00517944])

# %%
fig, ax = plt.subplots()
_ = plt.hist(x, color = 'green')

# %%
xbar = x.mean()
xbar
# Out:
# 0.5248572173461438

# %%
fig, ax = plt.subplots()
plt.axvline(x = x.mean(), color='orange')
_ = plt.hist(x, color = 'green')

# %%
np.median(x)
# Out:
# 0.4468676266914521

# %%
fig, ax = plt.subplots()
plt.axvline(x = np.mean(x), color='orange')
plt.axvline(x = np.median(x), color='red')
_ = plt.hist(x, color = 'green')

# %%
x.var()
# Out:
# 0.66508268347305

# %%
x.var()**(1/2)
# Out:
# 0.8155260164293043

# %%
sigma = x.std()
sigma
# Out:
# 0.8155260164293043

# %%
fig, ax = plt.subplots()
plt.axvline(x = xbar, color='orange')
plt.axvline(x = xbar+sigma, color='olivedrab')
plt.axvline(x = xbar-sigma, color='olivedrab')
_ = plt.hist(x, color = 'lightgray')

# %%
sigma/(x.size)**(1/2)
# Out:
# 0.025789197030404998

# %%
st.sem(x) # defaults to 1 degree of freedom, which can be ignored with the larger data sets of ML
# Out:
# 0.025802101307935272

# %%
st.sem(x, ddof=0)
# Out:
# 0.025789197030404998

# %%
x = np.random.normal(size=10000)

# %%
sns.set_style('ticks')

# %%
_ = sns.displot(x, kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x.mean()
# Out:
# -0.01626305454909193

# %%
x.std()
# Out:
# 1.0039756140435032

# %%
x_sample = np.random.choice(x, size=10, replace=False)
x_sample
# Out:
# array([-0.10069587,  1.35557294,  0.66536894, -3.17042574,  0.43948605,
#         0.53629091, -1.04552949, -0.99434937, -0.74023225, -0.54129909])

# %%
x_sample.mean()
# Out:
# -0.35958129882198664

# %%
def sample_mean_calculator(input_dist, sample_size, n_samples):
    sample_means = []
    for i in range(n_samples):
        sample = np.random.choice(input_dist, size=sample_size, replace=False)
        sample_means.append(sample.mean())
    return sample_means

# %%
sns.displot(sample_mean_calculator(x, 10, 10), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(sample_mean_calculator(x, 10, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(sample_mean_calculator(x, 100, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(sample_mean_calculator(x, 1000, 1000), color='green', kde=True)
_ = plt.xlim(-1.5, 1.5)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
s = st.skewnorm.rvs(10, size=10000)

# %%
_ = sns.displot(s, kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
_ = sns.displot(sample_mean_calculator(s, 10, 1000), color='green', kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
_ = sns.displot(sample_mean_calculator(s, 1000, 1000), color='green', kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
m = np.concatenate((np.random.normal(size=5000), np.random.normal(loc = 4.0, size=5000)))

# %%
_ = sns.displot(m, kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
_ = sns.displot(sample_mean_calculator(m, 1000, 1000), color='green', kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
u = np.random.uniform(size=10000)

# %%
_ = sns.displot(u)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
_ = sns.displot(sample_mean_calculator(u, 1000, 1000), color='green', kde=True)
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x_i = 60
mu = 40
sigma = 5

# %%
x = np.random.normal(mu, sigma, 10000)

# %%
sns.displot(x, color='gray')
ax.set_xlim(0, 100)
plt.axvline(mu, color='orange')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='olivedrab')
_ = plt.axvline(x_i, color='purple')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
z = (x_i - mu)/sigma
z
# Out:
# 4.0

# %%
z = (x_i - np.mean(x))/np.std(x)
z
# Out:
# 4.012840567584941

# %%
len(np.where(x > 85)[0])
# Out:
# 0

# %%
100*69/10000
# Out:
# 0.69

# %%
np.percentile(x, 99)
# Out:
# 51.67893529147331

# %%
mu = 90
sigma = 2

# %%
y = np.random.normal(mu, sigma, 10000)

# %%
sns.displot(y, color='gray')
plt.axvline(mu, color='orange')
for v in [-3, -2, -1, 1, 2, 3]:
    plt.axvline(mu+v*sigma, color='olivedrab')
_ = plt.axvline(x_i, color='purple')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
z = (x_i - mu)/sigma
z
# Out:
# -15.0

# %%
z = (x_i - np.mean(y))/np.std(y)
z
# Out:
# -14.853099100116568

# %%
len(np.where(y > 85)[0])
# Out:
# 9933

# %%
100*9933/10000
# Out:
# 99.33

# %%
10000-9933
# Out:
# 67

# %%
np.percentile(y, 1)
# Out:
# 85.3781445632019

# %%
p_below = st.norm.cdf(-2.5)
p_below
# Out:
# 0.006209665325776132

# %%
p_below*10000
# Out:
# 62.096653257761325

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu-2.5*sigma, color='blue')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
st.norm.cdf(2.5)
# Out:
# 0.9937903346742238

# %%
p_above = 1-st.norm.cdf(2.5)
p_above
# Out:
# 0.006209665325776159

# %%
p_above*10000
# Out:
# 62.09665325776159

# %%
sns.displot(y, color='gray')
_ = plt.axvline(mu+2.5*sigma, color='blue')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
p_outside = p_below + p_above
p_outside
# Out:
# 0.01241933065155229

# %%
p_outside*10000
# Out:
# 124.1933065155229

# %%
sns.displot(y, color='gray')
plt.axvline(mu+2.5*sigma, color='blue')
_ = plt.axvline(mu-2.5*sigma, color='blue')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
st.norm.ppf(.04)
# Out:
# -1.75068607125217

# %%
st.norm.ppf(.04)
# Out:
# -1.75068607125217

# %%
sns.displot(y, color='gray')
plt.axvline(mu+1.96*sigma, color='darkred')
_ = plt.axvline(mu-1.96*sigma, color='darkred')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
st.norm.ppf(.008)
# Out:
# -2.408915545815461

# %%
st.norm.ppf(.992)
# Out:
# 2.408915545815461

# %%
sns.displot(y, color='gray')

plt.axvline(mu+1.96*sigma, color='green')
plt.axvline(mu-1.96*sigma, color='green')

plt.axvline(mu+2.56*sigma, color='red')
_ = plt.axvline(mu-2.56*sigma, color='red')
# Out:
# C:\Users\CS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x = [48, 50, 54, 60]

# %%
xbar = np.mean(x)
xbar

# %%
sx = st.sem(x)
sx

# %%
t = (xbar-50)/sx
t

# %%
# my_n is number of observation that you wnat to compare it to the mean

def p_from_t(my_t, my_n):
    return 2 * st.t.cdf(-abs(my_t), my_n-1) # 2nd arg to t.cdf() is "degrees of freedom"

# %%
# when p_value is <0.5 mean the provided observation
# is not significantly differ from the provided mean
p_from_t(t, len(x))

# %%
st.ttest_1samp(x, 50)

# %%
penguins = sns.load_dataset('penguins').dropna() # some rows are missing data

# %%
penguins

# %%
np.unique(penguins.species, return_counts=True)

# %%
adelie = penguins[penguins.species == 'Adelie']

# %%
adelie

# %%
np.unique(adelie.island, return_counts=True)

# %%
np.unique(adelie.sex, return_counts=True)

# %%
_ = sns.boxplot(x='island', y='body_mass_g', hue='sex', data=adelie)

# %%
f = adelie[adelie.sex == 'Female']['body_mass_g'].to_numpy()/1000
f

# %%
m = adelie[adelie.sex == 'Male']['body_mass_g'].to_numpy()/1000
m

# %%
fbar = f.mean()
fbar

# %%
mbar = m.mean()
mbar

# %%
sf = f.var(ddof=1)
sm = m.var(ddof=1)

# %%
nf = f.size
nm = m.size

# %%
t = (fbar-mbar)/(sf/nf + sm/nm)**(1/2)
t
